# %%
# Name (שם מלא): Gal Davidi (גל דוידי)
# ID (תעודת זהות): 206555112

# Github link:
# https://github.com/gdavidi/Projects/tree/main/Yad2%20cars

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, date
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import calendar

# %%
# URL for Nissan's car listings on the ad.co.il website
url = 'https://www.ad.co.il/car?sp261=13903'
print("Nissan's cars page url is:", url)
# Out:
# Nissan's cars page url is: https://www.ad.co.il/car?sp261=13903

# %%
# Fetch the HTML content of the main Nissan page
html = requests.get(url)
nissan_page = BeautifulSoup(html.content, 'html.parser')

# %%
# Function to get posts from a specific page
def get_posts(page):
    url = f"https://www.ad.co.il/car?sp261=13903&pageindex={page}"
    response = requests.get(url)
    if response.status_code != 200:
        print("Error: status code", response.status_code)
        return None, None
    
    page_soup = BeautifulSoup(response.content, 'html.parser')
    posts = page_soup.find('div', {'class': "content mt-3"})
    posts_link = posts.find_all('div', {'class': 'card-body p-md-3'})
    posts_pic = posts.find_all('div', {"data-images": True})
    posts_links_list = ["https://www.ad.co.il" + post.find('a').get('href') for post in posts_link]
    
    posts_image_num_list = []
    for post in posts_pic:
        data_images = post.get("data-images")
        if data_images is not None:
            posts_image_num_list.append(int(data_images))
        else:
            posts_image_num_list.append(0)  # Default value if no images are present

    return posts_links_list, posts_image_num_list

# %%
# Function to get the total number of pages
def amount_of_pages():
    pages_n = nissan_page.find('h6', {'class': "ms-2 d-none d-sm-flex fs--1"})
    return int(pages_n.string.split(' ')[-1].split(')')[0])

# %%
# Function to fetch all posts across all pages
def fetch_all_pages():
    all_links = []
    all_images = []
    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(get_posts, page) for page in range(1, amount_of_pages() + 1)]
        for future in futures:
            links, images = future.result()
            if links and images:
                all_links.extend(links)
                all_images.extend(images)
    return all_links, all_images

# %%
# Helper function to replace commas in strings (used for prices)
def replace_comma(string):
    return int(string.replace(",", ""))

# %%
# Function to convert list of info from the post to a dictionary
def info_to_dict(info):
    keys_list = []
    values_list = []
    for index, value in enumerate(info):
        if index % 2 == 0:
            keys_list.append(str(value.string.strip()))
        else:
            values_list.append(str(value.string.strip()))
    return dict(zip(keys_list, values_list))

# %%
# Function to update keys in the dictionary from Hebrew to English
def update_or_add_keys(dictionary):
    heb_keys = ['שנה', 'יד', 'ת. הילוכים', 'נפח', 'סוג מנוע', 'ק"מ', 'טסט עד', 'צבע', 'בעלות קודמת', 'בעלות נוכחית', 'אזור', 'עיר']
    en_keys = ['Year', 'Hand', 'Gear', 'capacity_Engine', 'Engine_type', 'Km', 'Test', 'Color', 'Prev_ownership', 'Curr_ownership', 'Area', 'City']
    for heb_key, en_key in zip(heb_keys, en_keys):
        if heb_key in dictionary:
            dictionary[en_key] = dictionary.pop(heb_key)
        else:
            dictionary[en_key] = None
    return dictionary

# %%
# Function to extract and clean the description from sub-info
def desc(sub_info):
    if sub_info:
        post_description = sub_info.find('div', {'class': 'p-3'})
        if post_description:
            return post_description.find('p', {'class': 'text-word-break'}).get_text().strip().replace('\n', '')
    return None

# %%
# Function to extract creation and re-publication dates
def cre_repub_dates(sub_info):
    if sub_info:
        post_dates = sub_info.find('div', {'class': 'd-flex flex-row align-items-center justify-content-center flex-wrap'}).find_all('div', {'class': 'px-3'})
        cre_date_string = str(post_dates[0].string).split(" ")[-1]
        repub_date_string = str(post_dates[1].string).split(" ")[-1]
        dates_list = [datetime.strptime(cre_date_string, "%d/%m/%Y")]
        dates_list.append(datetime.strptime(repub_date_string, "%d/%m/%Y") if repub_date_string else None)
        return dates_list
    return [None, None]

# %%
# Function to calculate days until a given date (for the "Test" field)
def days_until(date_str):
    if date_str:
        given_date = datetime.strptime(date_str, "%m/%Y")
        _, last_day = calendar.monthrange(given_date.year, given_date.month)
        given_date = given_date.replace(day=last_day)
        current_date = date.today()
        return (given_date.date() - current_date).days
    return None

# %%
# Function to correct data types in the dataframe
def type_correction(df):
    df['Year'] = df['Year'].astype(int)
    df['Price'] = df['Price'].astype(float)
    df['Hand'] = df['Hand'].astype(int)
    df['Gear'] = df['Gear'].astype(str)
    df['Color'] = df['Color'].astype(str)
    df['Prev_ownership'] = df['Prev_ownership'].astype(str)
    df['Curr_ownership'] = df['Curr_ownership'].astype(str)
    df['Area'] = df['Area'].astype(str)
    df['City'] = df['City'].astype(str)
    df['Test'] = df['Test'].astype('Int64')
    try:
        df['capacity_Engine'] = df['capacity_Engine'].str.replace(',', '').astype(int)
        df['Km'] = df['Km'].str.replace(',', '').astype(int)
    except Exception:
        pass
    return df

# %%
# Function to fetch detailed information for a specific post
def fetch_post_details(link):
    post_page_response = requests.get(link)
    post_page = BeautifulSoup(post_page_response.content, 'html.parser')
    main_info = list(post_page.find('table', {'class': "table table-sm mb-4"}).find_all("td"))
    sub_info = post_page.find('div', {'class': "order-first order-sm-0"})
    
    details = {
        'model': str(post_page.find('div', {'class': "d-flex justify-content-between"}).find_all('h2')[0].string),
        'Price': replace_comma(str(post_page.find('div', {'class': "d-flex justify-content-between"}).find_all('h2')[1].string).split(' ')[0]),
        'Description': desc(sub_info),
        'Cre_date': cre_repub_dates(sub_info)[0],
        'Repub_date': cre_repub_dates(sub_info)[1]
    }
    info_dict = info_to_dict(main_info)
    updated_dict = update_or_add_keys(info_dict)
    details.update(updated_dict)
    return details

# %%
# Main code
all_links, all_images = fetch_all_pages()

data = []
with ThreadPoolExecutor() as executor:
    futures = [executor.submit(fetch_post_details, link) for link in all_links]
    for future in futures:
        data.append(future.result())

df = pd.DataFrame(data)
df['Pic_num'] = all_images
df.insert(0, 'manufactor', ['ניסאן'] * len(df))

df['Test'] = df['Test'].apply(days_until)
df = type_correction(df)
df = df.drop(columns=['תת דגם'])
df.to_csv('adNissanData.csv', index=False, encoding='utf-8-sig')

# %%
df
# Out:
#    manufactor            model     Price  \
# 0       ניסאן      ניסאן סנטרה   69900.0
# 1       ניסאן      ניסאן סנטרה   62000.0
# 2       ניסאן      ניסאן סנטרה   87000.0
# 3       ניסאן      ניסאן סנטרה   39500.0
# 4       ניסאן      ניסאן מיקרה   24000.0
# 5       ניסאן      ניסאן מיקרה   52500.0
# 6       ניסאן     ניסאן פרימרה   62000.0
# 7       ניסאן  ניסאן ג'וק JUKE  135000.0
# 8       ניסאן      ניסאן מיקרה   19000.0
# 9       ניסאן      ניסאן מיקרה   52500.0
# 10      ניסאן     ניסאן אלתימה   65000.0
# 11      ניסאן      ניסאן מיקרה   33500.0
# 12      ניסאן      ניסאן סנטרה   53000.0
# 13      ניסאן  ניסאן ג'וק JUKE   28000.0
# 14      ניסאן      ניסאן מיקרה   52500.0
# 15      ניסאן      ניסאן מיקרה   34000.0
# 16      ניסאן     ניסאן אלתימה   85000.0
# 17      ניסאן  ניסאן ג'וק JUKE   55000.0
# 18      ניסאן  ניסאן ג'וק JUKE   99000.0
# 19      ניסאן      ניסאן סנטרה   40000.0
# 20      ניסאן  ניסאן ג'וק JUKE   39000.0
# 21      ניסאן      ניסאן מיקרה   54000.0
# 22      ניסאן      ניסאן אלמרה    7000.0
# 23      ניסאן      ניסאן סנטרה  125000.0
# 24      ניסאן      ניסאן אלמרה    7900.0
# 25      ניסאן      ניסאן מיקרה   49500.0
# 26      ניסאן      ניסאן קווסט   23200.0
# 27      ניסאן      ניסאן מיקרה   13000.0
# 28      ניסאן  ניסאן ג'וק JUKE   41000.0
# 29      ניסאן  ניסאן ג'וק JUKE   43000.0
# 30      ניסאן      ניסאן אלמרה    5200.0
# 31      ניסאן       ניסאן טידה   10600.0
# 32      ניסאן       ניסאן טידה   12500.0
# 33      ניסאן      ניסאן מיקרה   31000.0
# 34      ניסאן  ניסאן ג'וק JUKE   73000.0
# 35      ניסאן  ניסאן ג'וק JUKE   30000.0
# 36      ניסאן       ניסאן טידה    8000.0
# 37      ניסאן  ניסאן ג'וק JUKE   30000.0
# 38      ניסאן      ניסאן מיקרה   49000.0
# 39      ניסאן     ניסאן מקסימה   99000.0
# 40      ניסאן      ניסאן אלמרה    3000.0
# 41      ניסאן     ניסאן אלתימה   98000.0
# 42      ניסאן  ניסאן ג'וק JUKE   41000.0
# 43      ניסאן      ניסאן מיקרה   22500.0
# 44      ניסאן  ניסאן ג'וק JUKE       1.0
# 45      ניסאן      ניסאן מיקרה   16000.0
# 46      ניסאן      ניסאן מיקרה   25000.0
# 47      ניסאן      ניסאן מיקרה   30000.0
# 48      ניסאן      ניסאן אלמרה   28000.0
# 49      ניסאן      ניסאן מיקרה   72000.0
# 50      ניסאן      ניסאן מיקרה      20.0
# 51      ניסאן      ניסאן מיקרה   34990.0
# 52      ניסאן        ניסאן נוט   23900.0
# 53      ניסאן      ניסאן מיקרה   25000.0
# 54      ניסאן       ניסאן טידה   12500.0
# 55      ניסאן     ניסאן SX 200   75000.0
# 56      ניסאן  ניסאן ג'וק JUKE   28000.0
# 57      ניסאן      ניסאן מיקרה   32000.0
# 58      ניסאן  ניסאן ג'וק JUKE   75000.0
#
#                                           Description   Cre_date Repub_date  \
# 0   למכירה: רכב ניסן סנטרה 2019 שמורה במצב מצוין! ... 2024-06-15 2024-06-15
# 1   רכב שמור ומטופל טסט לשנהרק 51000 ק״מ .נמצא בחי... 2024-06-21 2024-06-21
# 2   ניסאן סנטרה 2021 צבע אפור עם גג שחור יד 2 ידיי... 2024-06-23 2024-06-25
# 3   רכב שמור טוב וחזק. רכב מהמם יפייפה שמור מאוד מ... 2022-10-28 2024-06-02
# 4   מיקרה 2017 ידנית במצב חדששששש, יד שניה פרטית, ... 2024-05-28 2024-05-28
# 5                                 כל התוספות האפשריות 2024-04-26 2024-04-26
# 6   ניסאן דגם קשקאי רכב שמור ברמה גבוהה טיפולים בז... 2024-04-24 2024-04-24
# 7   ניסאן אקסל טרייל! (לא גוק - בעיה באתר)רמת גימו... 2024-04-12 2024-04-13
# 8   רכב בבעלות עמותה. נהג יחיד. נקנה חדש 0 ק"מ. טס... 2024-02-19 2024-04-04
# 9                       כל התוספות האפשריות דגם מפואר 2024-05-15 2024-05-15
# 10                            במצב מעולה, בלי תאונות. 2024-01-10 2024-02-08
# 11  רכב מצב מכני וחיצוני מצויין.. 0 תקלות .מאוד חי... 2023-10-03 2023-12-07
# 12                          יד ראשונה ליסינג נהג יחיד 2023-11-12 2023-11-20
# 13  רכב מתוחזק היטב ללא תאונות או תקלות, טסט עד או... 2023-08-31 2023-11-09
# 14      כל התוספות האפשריות. דגם אסנטה, 5 דלתות. לבן. 2024-04-23 2024-04-23
# 15  כל הקודם זוכה..... רכב בהיזדמנות .מצב מכני מצו... 2023-09-10 2023-10-01
# 16  ניסאן קשקאי.1200 טורבו.5 מקומות.שמור החדש רק 3... 2023-09-10 2023-09-12
# 17  רכב מטופל בחברה הרבה שנים. כמו חדש. המושבים הא... 2023-09-12 2023-09-12
# 18  דגם טקנה המפואר עם ריפודי עור בצבע בז'. 7 מקומ... 2023-07-24 2023-07-23
# 19  רכב מצוין בגא'ז גדול עם מערכת מולטימדיה חיישני... 2023-07-05 2023-07-05
# 20  מוכרת את הרכב שלי!נהגת יחידהמצב חדש! שמורה מאו... 2023-06-29 2023-06-29
# 21  שנת 2018, אוטומטהרכב במצב מעולה, מוכר עקב שדרו... 2023-06-01 2023-06-01
# 22  מצב מכני מצוין.5 דלתות.קילומטרדי נמוך.כל הפרטי... 2023-05-23 2023-05-23
# 23    יד ראשונה 0 קמ.מחב אלבר.שמורה.מטופלת ללא תאונות 2023-03-05 2023-03-05
# 24  נמכר בצער.מקבל רכב חדש. שמור ומטופל. כולל חישנ... 2023-02-10 2023-02-10
# 25          תוספות\r\t\t\t\tהוחלף מצבר חדש + 2 גלגלים 2023-01-30 2023-01-30
# 26  זה ניסאן קשקאי משום מה לא מופיע הרכב במצב מצוי... 2023-01-16 2023-01-16
# 27  NISSAN MICRA 2008יד2 פרטית230ק״מטסט 4/22מצב מכ... 2022-12-27 2022-12-27
# 28  למכירה ניסאן ג'וק 2014רכב שמור מאוד, מטופל במו... 2022-12-14 2022-12-25
# 29  נמכר בעקבות קבלת רכב מהעבודה.רכב שמור מאוד, לל... 2022-12-16 2022-12-18
# 30  מעולה מצב מצוין נעילה מרכזית עם בקרת חלונות או... 2022-10-18 2022-11-13
# 31  רכב פיצוץ נוסע חלק אמין מרווח שמור מטופל, ברקס... 2022-10-24 2022-11-08
# 32  רכב במצב מצוין, אחרי טיפול גדול, מזגן קור וחום... 2022-10-12 2022-10-12
# 33  רכב שמור, נהג יחיד, מטופל תמיד בזמן במוסך מורש... 2022-08-31 2022-09-12
# 34  ניסן גו'ק אסנטה בלאק7/2018 עם טסט לכמעט שנה שמ... 2022-08-29 2022-08-29
# 35                                               None 2022-08-15 2022-08-15
# 36                                               None 2022-06-26 2022-06-26
# 37  רכב במצב שמור מאוד. מולטימדיה 10 אינץ' חדשה וח... 2022-05-27 2022-05-27
# 38                                   שמורה כל התוספות 2022-04-06 2022-05-22
# 39                              שמורה מאוד כל התוספות 2022-05-21 2022-05-21
# 40  מוכרים עקב מעבר ל-7 מקומותמצב מכני טוב פרט לנז... 2022-05-03 2022-05-03
# 41  רכב במצב שמור ומעולה בהזדמנות, נהג יחיד ומבוגר... 2022-04-08 2022-04-08
# 42  למכירה ניסאן ג'וק 2014 יד 2 פרטית 109000 קילומ... 2022-04-05 2022-04-05
# 43  רכב שמור ונקי ללא תאונות 104 אלף קילומטר חימום... 2022-03-29 2022-03-29
# 44  למכירה ניסאן ג'וק 2014 יד 2 פרטית 108000 קילומ... 2022-03-15 2022-03-15
# 45  הרכב נוסע מצויין וחסכוני מאוד.עבר עוד בעלות בת... 2022-01-27 2022-01-27
# 46  ניסאן מיקרה במצב מצוין - ידיים פרטיות בלבד , ש... 2021-12-27 2021-12-27
# 47  רכב 5 דלתות חסכוני בדלק מפנק ואמין מאוד שמור ו... 2023-10-22 2023-10-22
# 48  רכב פצצה כל התוספות מסך, מצלמה, קרוז קונטרול ע... 2021-09-12 2021-10-02
# 49  ניסאן קשקאי 2017 125,000 קמ, טסט עד פברואר שמו... 2023-11-25 2023-11-25
# 50                                   רכב אלעלאא שפרעם 2023-08-30 2023-08-30
# 51  ניסאן מיקרה 2017 1.2 80 כ"ס אוט' החל מ-499 ש"ח... 2023-04-02 2023-05-15
# 52                                     ניסאן נוט 2013 2023-06-21 2023-06-21
# 53  רכב במצב טוב, מנוע במצב מעולה!עבר טיפול 15, עו... 2023-03-10 2023-03-10
# 54  מנוע וגיר מצוין מזגו עובד קור וחום אחרי טיפול ... 2022-10-19 2022-10-19
# 55  קשקאי 1200 טורבו.יד ראשונה.נהגת יחידה.טסט עד י... 2023-01-10 2023-01-10
# 56  שמור ומיוחד, לבוא לראות ולקחת מתחייב בבדיקה גמ... 2022-08-05 2022-08-04
# 57  רכב במצב מעולה! אמין! חסכוני! מתחייבת בבדיקה! ... 2022-06-13 2022-06-13
# 58                                               None 2021-11-22 2021-11-22
#
#     Year  Hand      Gear  capacity_Engine Engine_type      Km  Test  \
# 0   2019     2  אוטומטית             1600       בנזין   69900   212
# 1   2019     2  אוטומטית             1800       בנזין   51000  <NA>
# 2   2021     2  אוטומטית             2000       בנזין   33000   120
# 3   2017     2  אוטומטית             1800       בנזין  127000  <NA>
# 4   2017     2     ידנית             1200       בנזין  180000   240
# 5   2020     2     ידנית             1000       בנזין   72200   301
# 6   2017     1  אוטומטית             1200       בנזין   90000  <NA>
# 7   2021     1  אוטומטית             1600       בנזין   38000    89
# 8   2018     2     ידנית             1200       בנזין  186825  <NA>
# 9   2020     3     ידנית             1000       בנזין   73000   332
# 10  2016     3  אוטומטית             1600        דיזל   80000  <NA>
# 11  2018     2  אוטומטית             1200       בנזין  134000  <NA>
# 12  2017     1  אוטומטית             1800       בנזין   85000  <NA>
# 13  2011     3  אוטומטית             1600       בנזין  118000  <NA>
# 14  2020     2     ידנית             1000       בנזין   70000   332
# 15  2018     2  אוטומטית             1200       בנזין  133000  <NA>
# 16  2018     3  אוטומטית             1200       בנזין   30000  <NA>
# 17  2016     1  אוטומטית             1600       בנזין  108000  <NA>
# 18  2017     2  אוטומטית             1600        דיזל  116000  <NA>
# 19  2017     2  אוטומטית             1800       בנזין  170000  <NA>
# 20  2013     3  אוטומטית             1600       בנזין   92000  <NA>
# 21  2018     1  אוטומטית             1200       בנזין  102000  <NA>
# 22  2023     2  אוטומטית             1800       בנזין  142000  <NA>
# 23  2020     1  אוטומטית             1300       בנזין   48000  <NA>
# 24  2006     3  אוטומטית             1800       בנזין  209300  <NA>
# 25  2018     1  אוטומטית             1200       בנזין   50000  <NA>
# 26  2010     5  אוטומטית             2000       בנזין  242000  <NA>
# 27  2008     3  אוטומטית             1400       בנזין     230  <NA>
# 28  2014     4  אוטומטית             1600       בנזין   72000  <NA>
# 29  2013     2  אוטומטית             1600       בנזין   65000  <NA>
# 30  2005     5  אוטומטית             1800       בנזין  265000  <NA>
# 31  2008     4  אוטומטית             1600       בנזין  236000  <NA>
# 32  2009     3  אוטומטית             1600       בנזין  200000  <NA>
# 33  2016     2     ידנית             1200       בנזין  109000  <NA>
# 34  2018     2  אוטומטית             1600       בנזין   85000  <NA>
# 35  2011     5  אוטומטית             1600       בנזין  130000  <NA>
# 36  2010     4  אוטומטית             1600       בנזין  250000  <NA>
# 37  2011     3  אוטומטית             1600       בנזין  169700  <NA>
# 38  2018     1  אוטומטית             1200       בנזין   69000  <NA>
# 39  2016     1  אוטומטית             3500       בנזין  119000  <NA>
# 40  2002     2  אוטומטית             1800       בנזין  190000  <NA>
# 41  2018     2  אוטומטית             2500       בנזין   71500  <NA>
# 42  2014     2  אוטומטית             1600       בנזין  109000  <NA>
# 43  2014     3     ידנית             1200       בנזין  104000  <NA>
# 44  2014     2  אוטומטית             1600       בנזין  108000  <NA>
# 45  2012     4  אוטומטית             1200       בנזין  173000  <NA>
# 46  2014     3  אוטומטית             1200       בנזין  129300  <NA>
# 47  2016     2  אוטומטית             1200       בנזין  165000  <NA>
# 48  2015     3  אוטומטית             1600       בנזין  121000  <NA>
# 49  2017     2  אוטומטית             1200       בנזין  125000  <NA>
# 50  2015     3     ידנית             1200       בנזין  118000  <NA>
# 51  2017     1  אוטומטית             1200       בנזין  135000  <NA>
# 52  2013     5  אוטומטית             1100       בנזין     150  <NA>
# 53  2015     3  אוטומטית             1200       בנזין  155000  <NA>
# 54  2009     3  אוטומטית             1600       בנזין   20000  <NA>
# 55  2016     1  אוטומטית             1200       בנזין   80500  <NA>
# 56  2011     4  אוטומטית             1600       בנזין  135000  <NA>
# 57  2015     1    אוטומט             1198       בנזין  131000  <NA>
# 58  2020     1  אוטומטית             1500       בנזין  100000  <NA>
#
#          Color Prev_ownership Curr_ownership                Area  \
# 0   כסוף מטאלי          פרטית          פרטית    רמת גן - גבעתיים
# 1    אפור עכבר          פרטית          פרטית     חיפה וחוף הכרמל
# 2   אפור מטאלי          פרטית          פרטית      ראשל"צ והסביבה
# 3   כסוף מטאלי         ליסינג          פרטית     ירושלים והסביבה
# 4         אפור          פרטית          פרטית      כרמיאל והסביבה
# 5     לבן שנהב          פרטית          פרטית     חיפה וחוף הכרמל
# 6    לבן מטאלי          פרטית          פרטית     ירושלים והסביבה
# 7   אפור מטאלי            אחר          פרטית    פתח תקוה והסביבה
# 8         כסוף         ליסינג           חברה    פתח תקוה והסביבה
# 9          לבן          פרטית          פרטית     חיפה וחוף הכרמל
# 10    לבן שנהב          פרטית          פרטית    פתח תקוה והסביבה
# 11    כסף מטלי          פרטית         ליסינג      אשדוד - אשקלון
# 12        שחור            אחר          פרטית       נתניה והסביבה
# 13  אפור מטאלי          פרטית          פרטית      אשדוד - אשקלון
# 14   לבן פנינה          פרטית          פרטית     חיפה וחוף הכרמל
# 15  כסוף מטאלי         ליסינג          פרטית      אשדוד - אשקלון
# 16         לבן          פרטית          פרטית         אילת והערבה
# 17        צהוב          פרטית          פרטית         גליל ועמקים
# 18        שחור          פרטית          פרטית    פרדס חנה - כרכור
# 19  אפור מטאלי          השכרה          פרטית               קריות
# 20        שחור          פרטית          פרטית   נס ציונה - רחובות
# 21        שחור          פרטית          פרטית     זכרון - בנימינה
# 22        שחור          פרטית          פרטית      אשדוד - אשקלון
# 23         לבן         ליסינג          פרטית        מושבים בשרון
# 24        אפור          פרטית          פרטית      יישובי השומרון
# 25         לבן          פרטית          פרטית      יישובי השומרון
# 26         לבן          פרטית          פרטית     בית שמש והסביבה
# 27  אפור מטאלי          פרטית          פרטית   נס ציונה - רחובות
# 28         לבן          פרטית          פרטית     בית שמש והסביבה
# 29  אפור מטאלי          פרטית          פרטית   גדרה יבנה והסביבה
# 30        אפור          פרטית          פרטית     ירושלים והסביבה
# 31  אפור מטאלי          פרטית          פרטית     מודיעין והסביבה
# 32  אפור מטאלי          פרטית          פרטית     באר שבע והסביבה
# 33    כסף מטלי          פרטית          פרטית     ירושלים והסביבה
# 34   אפור עכבר          פרטית          פרטית   נס ציונה - רחובות
# 35        שחור          פרטית          פרטית       טבריה והסביבה
# 36        כסוף          פרטית          פרטית                None
# 37         לבן          פרטית          פרטית     רעננה - כפר סבא
# 38   כחול בהיר          פרטית          פרטית        מושבים בשרון
# 39   לבן מטאלי          פרטית          פרטית        מושבים בשרון
# 40        אפור          פרטית          פרטית      אשדוד - אשקלון
# 41   לבן פנינה          פרטית          פרטית    ראש העין והסביבה
# 42        שחור          פרטית          פרטית          רמלה - לוד
# 43        כחול          פרטית          פרטית                None
# 44        שחור          פרטית          פרטית          רמלה - לוד
# 45         לבן          פרטית          פרטית     בית שמש והסביבה
# 46  אפור מטאלי          פרטית          פרטית   גדרה יבנה והסביבה
# 47        כסוף          פרטית          פרטית     ירושלים והסביבה
# 48         לבן         ליסינג          פרטית     ירושלים והסביבה
# 49         לבן          פרטית          פרטית     באר שבע והסביבה
# 50        אפור         ליסינג         ליסינג         גליל ועמקים
# 51    לבן שנהב         ליסינג         ליסינג      אשדוד - אשקלון
# 52         לבן          פרטית          פרטית     ירושלים והסביבה
# 53   אפור עכבר           חברה          פרטית       חולון - בת ים
# 54   אפור עכבר          פרטית          פרטית     באר שבע והסביבה
# 55   לבן פנינה          פרטית          פרטית  רמת השרון - הרצליה
# 56        שחור          פרטית          פרטית     חיפה וחוף הכרמל
# 57        כסוף           None         ליסינג      ראשל"צ והסביבה
# 58         לבן           חברה          פרטית     באר שבע והסביבה
#
#                 City  Pic_num
# 0             רמת גן        4
# 1               חיפה        3
# 2            בית דגן        5
# 3            ירושלים        6
# 4             כרמיאל        6
# 5               חיפה        5
# 6            ירושלים        6
# 7          פתח תקווה        8
# 8          פתח תקווה        4
# 9               חיפה        0
# 10         פתח תקווה       10
# 11            אשקלון        3
# 12             נתניה        2
# 13             אשדוד        4
# 14              חיפה        0
# 15            אשקלון        3
# 16              אילת        1
# 17             שפרעם        7
# 18              חריש        9
# 19       קרית ביאליק        4
# 20            רחובות        5
# 21  בנימינה גבעת עדה        3
# 22             אשדוד        3
# 23           גן חיים        2
# 24               עלי        4
# 25        שערי תקווה        3
# 26           בית שמש        6
# 27            רחובות        9
# 28           בית שמש       10
# 29              יבנה        5
# 30           ירושלים        2
# 31     מודיעין עילית        4
# 32           באר שבע        2
# 33           ירושלים        7
# 34            רחובות        6
# 35              מגאר        4
# 36            תל שבע        7
# 37             רעננה        5
# 38         אבן יהודה        2
# 39         אבן יהודה        2
# 40             אשדוד        3
# 41          ראש העין        6
# 42              רמלה        4
# 43        משמר השרון        9
# 44              רמלה        4
# 45           בית שמש        3
# 46              יבנה        3
# 47           ירושלים        5
# 48           ירושלים        2
# 49           קרית גת        0
# 50             שפרעם        2
# 51            אשקלון        4
# 52           ירושלים        0
# 53             חולון        4
# 54           באר שבע        9
# 55            הרצליה        0
# 56              חיפה        5
# 57       ראשון לציון        3
# 58           באר שבע        0
